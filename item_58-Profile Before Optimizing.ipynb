# %%
def insertion_sort(data):
    result = []
    for value in data:
        insert_value(result, value)
    return result

# %%
def insert_value(array, value):
    for i, existing in enumerate(array):
        if existing > value:
            array.insert(i, value)
            return
    array.append(value)

# %%
from random import randint

max_size = 10**4
data = [randint(0, max_size) for _ in range(max_size)]
test = lambda: insertion_sort(data)

# %%
from cProfile import Profile

profiler = Profile()
profiler.runcall(test)
# Out:
# [0,
#  4,
#  4,
#  5,
#  5,
#  6,
#  7,
#  8,
#  11,
#  12,
#  15,
#  15,
#  16,
#  17,
#  18,
#  18,
#  19,
#  22,
#  23,
#  23,
#  24,
#  24,
#  26,
#  26,
#  27,
#  28,
#  28,
#  29,
#  31,
#  35,
#  37,
#  38,
#  38,
#  42,
#  43,
#  43,
#  43,
#  43,
#  43,
#  45,
#  46,
#  46,
#  47,
#  48,
#  49,
#  49,
#  50,
#  50,
#  52,
#  55,
#  55,
#  56,
#  56,
#  58,
#  59,
#  59,
#  60,
#  60,
#  61,
#  62,
#  63,
#  64,
#  64,
#  65,
#  66,
#  67,
#  68,
#  70,
#  70,
#  71,
#  72,
#  72,
#  72,
#  72,
#  73,
#  73,
#  74,
#  74,
#  76,
#  77,
#  78,
#  78,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  89,
#  90,
#  93,
#  93,
#  94,
#  94,
#  95,
#  96,
#  97,
#  98,
#  98,
#  99,
#  99,
#  99,
#  100,
#  100,
#  101,
#  103,
#  107,
#  108,
#  111,
#  112,
#  115,
#  115,
#  116,
#  117,
#  118,
#  120,
#  120,
#  121,
#  124,
#  126,
#  127,
#  130,
#  132,
#  133,
#  136,
#  136,
#  138,
#  139,
#  140,
#  142,
#  142,
#  142,
#  143,
#  143,
#  144,
#  144,
#  146,
#  147,
#  147,
#  150,
#  152,
#  152,
#  152,
#  153,
#  154,
#  157,
#  159,
#  160,
#  161,
#  162,
#  164,
#  165,
#  167,
#  167,
#  168,
#  170,
#  170,
#  171,
#  174,
#  174,
#  175,
#  175,
#  176,
#  177,
#  177,
#  178,
#  179,
#  179,
#  179,
#  181,
#  182,
#  183,
#  183,
#  185,
#  186,
#  186,
#  186,
#  188,
#  188,
#  189,
#  189,
#  190,
#  193,
#  193,
#  194,
#  196,
#  200,
#  202,
#  203,
#  209,
#  209,
#  211,
#  212,
#  212,
#  213,
#  213,
#  213,
#  215,
#  215,
#  216,
#  217,
#  220,
#  222,
#  222,
#  223,
#  223,
#  225,
#  228,
#  229,
#  229,
#  230,
#  230,
#  230,
#  230,
#  230,
#  232,
#  232,
#  233,
#  233,
#  235,
#  236,
#  236,
#  239,
#  239,
#  239,
#  239,
#  239,
#  240,
#  241,
#  242,
#  245,
#  245,
#  248,
#  248,
#  248,
#  253,
#  253,
#  253,
#  255,
#  256,
#  258,
#  259,
#  260,
#  260,
#  261,
#  261,
#  264,
#  265,
#  265,
#  265,
#  266,
#  267,
#  269,
#  271,
#  271,
#  272,
#  273,
#  275,
#  277,
#  277,
#  277,
#  278,
#  279,
#  279,
#  282,
#  283,
#  285,
#  289,
#  289,
#  290,
#  291,
#  291,
#  291,
#  292,
#  293,
#  296,
#  297,
#  303,
#  303,
#  304,
#  306,
#  306,
#  306,
#  309,
#  309,
#  312,
#  313,
#  313,
#  314,
#  315,
#  315,
#  317,
#  318,
#  319,
#  319,
#  321,
#  322,
#  323,
#  324,
#  325,
#  325,
#  327,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  335,
#  336,
#  336,
#  338,
#  338,
#  339,
#  340,
#  341,
#  344,
#  346,
#  348,
#  350,
#  351,
#  351,
#  352,
#  352,
#  353,
#  353,
#  354,
#  354,
#  354,
#  355,
#  355,
#  356,
#  359,
#  359,
#  361,
#  361,
#  362,
#  363,
#  363,
#  364,
#  364,
#  364,
#  364,
#  366,
#  367,
#  370,
#  370,
#  370,
#  372,
#  372,
#  372,
#  372,
#  373,
#  373,
#  373,
#  374,
#  375,
#  375,
#  376,
#  376,
#  376,
#  376,
#  377,
#  378,
#  378,
#  378,
#  380,
#  380,
#  381,
#  382,
#  384,
#  385,
#  388,
#  392,
#  394,
#  394,
#  397,
#  397,
#  402,
#  403,
#  407,
#  408,
#  410,
#  411,
#  412,
#  412,
#  412,
#  414,
#  415,
#  416,
#  416,
#  417,
#  417,
#  417,
#  417,
#  419,
#  421,
#  423,
#  423,
#  425,
#  426,
#  426,
#  427,
#  429,
#  430,
#  431,
#  431,
#  431,
#  434,
#  437,
#  437,
#  441,
#  441,
#  442,
#  442,
#  443,
#  445,
#  446,
#  447,
#  447,
#  450,
#  450,
#  451,
#  455,
#  455,
#  457,
#  457,
#  459,
#  461,
#  461,
#  462,
#  462,
#  463,
#  463,
#  463,
#  466,
#  466,
#  468,
#  469,
#  470,
#  470,
#  470,
#  470,
#  471,
#  471,
#  472,
#  472,
#  472,
#  476,
#  476,
#  476,
#  477,
#  478,
#  478,
#  479,
#  480,
#  480,
#  481,
#  482,
#  483,
#  484,
#  484,
#  485,
#  485,
#  485,
#  486,
#  486,
#  487,
#  487,
#  488,
#  491,
#  492,
#  493,
#  494,
#  494,
#  494,
#  495,
#  496,
#  497,
#  497,
#  497,
#  498,
#  499,
#  501,
#  501,
#  502,
#  504,
#  505,
#  506,
#  507,
#  507,
#  508,
#  512,
#  514,
#  515,
#  515,
#  515,
#  516,
#  517,
#  519,
#  519,
#  519,
#  521,
#  523,
#  523,
#  523,
#  523,
#  528,
#  530,
#  531,
#  532,
#  533,
#  533,
#  534,
#  534,
#  534,
#  537,
#  537,
#  537,
#  537,
#  539,
#  539,
#  541,
#  542,
#  543,
#  544,
#  544,
#  545,
#  545,
#  546,
#  549,
#  550,
#  551,
#  552,
#  554,
#  555,
#  556,
#  558,
#  559,
#  561,
#  561,
#  562,
#  562,
#  564,
#  565,
#  565,
#  565,
#  566,
#  567,
#  567,
#  568,
#  569,
#  569,
#  570,
#  573,
#  573,
#  579,
#  580,
#  580,
#  581,
#  581,
#  581,
#  582,
#  582,
#  584,
#  584,
#  584,
#  586,
#  588,
#  588,
#  588,
#  589,
#  590,
#  594,
#  594,
#  596,
#  599,
#  600,
#  601,
#  601,
#  603,
#  603,
#  603,
#  604,
#  604,
#  604,
#  605,
#  606,
#  606,
#  607,
#  607,
#  608,
#  611,
#  612,
#  613,
#  613,
#  613,
#  614,
#  614,
#  614,
#  615,
#  615,
#  616,
#  616,
#  617,
#  618,
#  619,
#  620,
#  623,
#  624,
#  624,
#  627,
#  628,
#  628,
#  628,
#  629,
#  629,
#  629,
#  631,
#  631,
#  632,
#  632,
#  633,
#  635,
#  635,
#  635,
#  636,
#  636,
#  636,
#  637,
#  637,
#  637,
#  638,
#  639,
#  639,
#  645,
#  645,
#  646,
#  646,
#  646,
#  649,
#  651,
#  651,
#  652,
#  654,
#  655,
#  656,
#  659,
#  659,
#  660,
#  661,
#  662,
#  663,
#  664,
#  664,
#  666,
#  666,
#  669,
#  669,
#  670,
#  670,
#  672,
#  674,
#  674,
#  677,
#  679,
#  679,
#  682,
#  683,
#  687,
#  689,
#  690,
#  690,
#  692,
#  693,
#  693,
#  693,
#  696,
#  698,
#  698,
#  699,
#  699,
#  700,
#  701,
#  701,
#  702,
#  703,
#  705,
#  706,
#  707,
#  707,
#  711,
#  712,
#  714,
#  715,
#  716,
#  716,
#  717,
#  718,
#  719,
#  722,
#  722,
#  723,
#  725,
#  726,
#  726,
#  728,
#  729,
#  729,
#  730,
#  731,
#  731,
#  731,
#  732,
#  733,
#  733,
#  735,
#  737,
#  738,
#  739,
#  739,
#  740,
#  742,
#  743,
#  744,
#  744,
#  745,
#  746,
#  751,
#  752,
#  755,
#  759,
#  760,
#  761,
#  761,
#  762,
#  762,
#  764,
#  766,
#  767,
#  767,
#  768,
#  769,
#  771,
#  771,
#  773,
#  774,
#  776,
#  777,
#  777,
#  778,
#  783,
#  784,
#  785,
#  785,
#  787,
#  788,
#  789,
#  790,
#  790,
#  791,
#  791,
#  794,
#  796,
#  796,
#  798,
#  800,
#  800,
#  802,
#  803,
#  804,
#  805,
#  806,
#  806,
#  808,
#  809,
#  810,
#  810,
#  811,
#  813,
#  816,
#  817,
#  818,
#  818,
#  819,
#  820,
#  821,
#  821,
#  822,
#  822,
#  823,
#  825,
#  825,
#  826,
#  826,
#  827,
#  831,
#  831,
#  831,
#  832,
#  833,
#  836,
#  836,
#  837,
#  841,
#  842,
#  843,
#  843,
#  846,
#  847,
#  849,
#  849,
#  850,
#  851,
#  851,
#  852,
#  853,
#  854,
#  855,
#  856,
#  856,
#  862,
#  862,
#  863,
#  865,
#  866,
#  866,
#  867,
#  868,
#  870,
#  872,
#  872,
#  872,
#  874,
#  877,
#  878,
#  879,
#  880,
#  881,
#  882,
#  883,
#  886,
#  887,
#  887,
#  887,
#  892,
#  892,
#  893,
#  893,
#  894,
#  894,
#  895,
#  895,
#  896,
#  896,
#  897,
#  897,
#  897,
#  898,
#  899,
#  900,
#  901,
#  903,
#  903,
#  904,
#  905,
#  906,
#  906,
#  907,
#  907,
#  907,
#  909,
#  910,
#  911,
#  912,
#  913,
#  915,
#  916,
#  917,
#  917,
#  918,
#  918,
#  921,
#  921,
#  921,
#  921,
#  922,
#  923,
#  924,
#  926,
#  929,
#  930,
#  930,
#  931,
#  931,
#  932,
#  932,
#  932,
#  936,
#  937,
#  938,
#  938,
#  939,
#  940,
#  940,
#  941,
#  943,
#  944,
#  948,
#  948,
#  949,
#  950,
#  952,
#  955,
#  958,
#  958,
#  959,
#  960,
#  960,
#  962,
#  964,
#  964,
#  965,
#  966,
#  966,
#  967,
#  967,
#  968,
#  968,
#  970,
#  971,
#  971,
#  971,
#  972,
#  973,
#  973,
#  975,
#  976,
#  978,
#  981,
#  982,
#  984,
#  985,
#  985,
#  987,
#  987,
#  988,
#  989,
#  992,
#  992,
#  993,
#  995,
#  995,
#  995,
#  996,
#  996,
#  996,
#  998,
#  1000,
#  1000,
#  1000,
#  1004,
#  1005,
#  1006,
#  1007,
#  1007,
#  1008,
#  1008,
#  1009,
#  1010,
#  1011,
#  1012,
#  1012,
#  1013,
#  1013,
#  1013,
#  1016,
#  1016,
#  1017,
#  1019,
#  1020,
#  1021,
#  1021,
#  1022,
#  1024,
#  1026,
#  1027,
#  1027,
#  1029,
#  1029,
#  1029,
#  1030,
#  1030,
#  1030,
#  1031,
#  1032,
#  ...]

# %%
import sys
from pstats import Stats
from sys import stdout as STDOUT

stats = Stats(profiler)
stats = Stats(profiler, stream=STDOUT)
stats.strip_dirs()
stats.sort_stats('cumulative')
stats.print_stats()
# Out:
#          20003 function calls in 2.237 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    2.237    2.237 <ipython-input-3-131684bee14e>:5(<lambda>)
#         1    0.004    0.004    2.237    2.237 <ipython-input-1-2296d37c636a>:1(insertion_sort)
#     10000    2.215    0.000    2.234    0.000 <ipython-input-2-45fd2124c9a1>:1(insert_value)
#      9991    0.019    0.000    0.019    0.000 {method 'insert' of 'list' objects}
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
from bisect import bisect_left

def insert_value(array, value):
    i = bisect_left(array, value)
    array.insert(i, value)

profiler = Profile()
profiler.runcall(test)
stats = Stats(profiler, stream=STDOUT)
stats.strip_dirs()
stats.sort_stats('cumulative')
stats.print_stats()
# Out:
#          30003 function calls in 0.033 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.033    0.033 <ipython-input-3-131684bee14e>:5(<lambda>)
#         1    0.003    0.003    0.033    0.033 <ipython-input-1-2296d37c636a>:1(insertion_sort)
#     10000    0.005    0.000    0.030    0.000 <ipython-input-6-07e324b0ee63>:3(insert_value)
#     10000    0.018    0.000    0.018    0.000 {method 'insert' of 'list' objects}
#     10000    0.006    0.000    0.006    0.000 {built-in method _bisect.bisect_left}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
def my_utility(a, b):
    c = 1
    for i in range(100):
        c += a * b

def first_func():
    for _ in range(1000):
        my_utility(4, 5)

def second_func():
    for _ in range(10):
        my_utility(1, 3)

def my_program():
    for _ in range(20):
        first_func()
        second_func()

# %%
profiler = Profile()
profiler.runcall(my_program)
stats = Stats(profiler, stream=STDOUT)
stats.strip_dirs()
stats.sort_stats('cumulative')
stats.print_stats()
# Out:
#          20242 function calls in 0.185 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.185    0.185 <ipython-input-7-0147e640b081>:14(my_program)
#        20    0.005    0.000    0.183    0.009 <ipython-input-7-0147e640b081>:6(first_func)
#     20200    0.180    0.000    0.180    0.000 <ipython-input-7-0147e640b081>:1(my_utility)
#        20    0.000    0.000    0.002    0.000 <ipython-input-7-0147e640b081>:10(second_func)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
stats = Stats(profiler, stream=STDOUT)
stats.strip_dirs()
stats.sort_stats('cumulative')
stats.print_callers()
# Out:
#    Ordered by: cumulative time
#
# Function                                          was called by...
#                                                       ncalls  tottime  cumtime
# <ipython-input-7-0147e640b081>:14(my_program)     <-
# <ipython-input-7-0147e640b081>:6(first_func)      <-      20    0.005    0.183  <ipython-input-7-0147e640b081>:14(my_program)
# <ipython-input-7-0147e640b081>:1(my_utility)      <-   20000    0.178    0.178  <ipython-input-7-0147e640b081>:6(first_func)
#                                                          200    0.002    0.002  <ipython-input-7-0147e640b081>:10(second_func)
# <ipython-input-7-0147e640b081>:10(second_func)    <-      20    0.000    0.002  <ipython-input-7-0147e640b081>:14(my_program)
# {method 'disable' of '_lsprof.Profiler' objects}  <-
